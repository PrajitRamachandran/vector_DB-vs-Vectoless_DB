# %%
# Cell 1
import sys
sys.path.append("..")
from vector_rag.pipeline import VectorRAGPipeline

vector_rag = VectorRAGPipeline()
# Out:
# 🔧 Initialising Vector RAG Pipeline...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ✅ Loaded ChromaDB index: 2108 vectors.
# ✅ Groq client ready — model: llama-3.3-70b-versatile
# ✅ Vector RAG Pipeline ready

# %%
# Cell 2
result = vector_rag.ask("What was NVIDIA's total revenue?")
vector_rag.show(result)
# Out:
#    🎯 Company filter applied: NVIDIA
# 🔁 Loading reranker: cross-encoder/ms-marco-MiniLM-L-6-v2
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# ✅ Reranker ready
#
# ...
#   METHOD  : Vector RAG (ChromaDB + Sentence Transformers)
# ...
#   QUESTION: What was NVIDIA's total revenue?
# ───────────────────────────────────────────────────────
#   ANSWER  :
#   NVIDIA's total revenue was $215,938 million for the year ended Jan 25, 2026, $130,497 million for the year ended Jan 26, 2025, and $60,922 million for the year ended Jan 28, 2024.
# ───────────────────────────────────────────────────────
#   SOURCES :
# ...

# %%
# Cell 3 — try a few more
questions = [
    "What are the main risk factors for Microsoft?",
    "How much did Netflix spend on content?",
    "What is Amazon's cloud revenue?"
]

for q in questions:
    r = vector_rag.ask(q)
    vector_rag.show(r)
# Out:
#    🎯 Company filter applied: MICROSOFT
#
# ...
#   METHOD  : Vector RAG (ChromaDB + Sentence Transformers)
# ...
#   QUESTION: What are the main risk factors for Microsoft?
# ───────────────────────────────────────────────────────
#   ANSWER  :
#   For Microsoft, the main risk factors include strategic and competitive risks, cybersecurity threats, legislative and regulatory actions, and legal, regulatory, and litigation risks. These risks could adversely affect Microsoft's business, operations, financial condition, results of operations, liquidity, and the trading price of its common stock. Specific risks mentioned include intense competition, security threats, product vulnerabilities, and potential legal claims or enforcement actions.
# ───────────────────────────────────────────────────────
#   SOURCES :
#     • MICROSOFT | Page 2 | Score: 0.6663
#     • MICROSOFT | Page 16 | Score: 0.6957
#     • MICROSOFT | Page 20 | Score: 0.6461
#     • MICROSOFT | Page 25 | Score: 0.6449
# ...
