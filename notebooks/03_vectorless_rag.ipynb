# %%
# Cell 1
import sys
sys.path.append("..")
from vectorless_rag.pipeline import VectorlessRAGPipeline

vectorless_rag = VectorlessRAGPipeline()
# Out:
# 🔧 Initialising Vectorless RAG Pipeline...
# ✅ Loaded BM25 index: 2108 chunks
# ✅ Groq client ready — model: llama-3.3-70b-versatile
# ✅ Vectorless RAG Pipeline ready

# %%
# Cell 2 — exact same questions as notebook 02 for fair comparison
result = vectorless_rag.ask("What was NVIDIA's total revenue?")
vectorless_rag.show(result)
# Out:
#    🎯 Company filter applied: NVIDIA (443/2108 chunks)
# 🔁 Loading reranker: cross-encoder/ms-marco-MiniLM-L-6-v2
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# ✅ Reranker ready
#
# =======================================================
#   METHOD  : Vectorless RAG (BM25 keyword search)
# =======================================================
#   QUESTION: What was NVIDIA's total revenue?
# ───────────────────────────────────────────────────────
#   ANSWER  :
#   NVIDIA's total revenue for fiscal year 2026 was $215.9 billion, up 65% from a year ago, and $130.5 billion for fiscal year 2025.
# ───────────────────────────────────────────────────────
#   SOURCES :
#     • NVIDIA | Page 78 | Score: 4.7275
#     • NVIDIA | Page 61 | Score: 3.9635
#     • NVIDIA | Page 64 | Score: 3.7884
#     • NVIDIA | Page 56 | Score: 3.6881
#     • NVIDIA | Page 35 | Score: 4.7799
#     • NVIDIA | Page 40 | Score: 5.7028
#     • NVIDIA | Page 3 | Score: 5.0182
#     • NVIDIA | Page 37 | Score: 3.9815
# ───────────────────────────────────────────────────────
#   Retrieval : 8.2967s
#   Generation: 0.7142s
#   Total     : 9.0109s
# =======================================================

# %%
# Cell 3
questions = [
    "What are the main risk factors for Microsoft?",
    "How much did Netflix spend on content?",
    "What is Amazon's cloud revenue?"
]

for q in questions:
    r = vectorless_rag.ask(q)
    vectorless_rag.show(r)
# Out:
#    🎯 Company filter applied: MICROSOFT (671/2108 chunks)
#
# =======================================================
#   METHOD  : Vectorless RAG (BM25 keyword search)
# =======================================================
#   QUESTION: What are the main risk factors for Microsoft?
# ───────────────────────────────────────────────────────
#   ANSWER  :
#   For Microsoft, the main risk factors include strategic and competitive risks, such as intense competition across all markets for its products and services. Additionally, the company faces risks related to economic conditions, geopolitical factors, climate change, and regulatory matters. The context also mentions cybersecurity risks and the potential impact of global pandemics on its business, operations, financial condition, and results of operations.
# ───────────────────────────────────────────────────────
#   SOURCES :
#     • MICROSOFT | Page 2 | Score: 11.942
#     • MICROSOFT | Page 16 | Score: 11.3624
#     • MICROSOFT | Page 36 | Score: 9.5673
#     • MICROSOFT | Page 4 | Score: 8.0976
#     • MICROSOFT | Page 13 | Score: 12.7704
#     • MICROSOFT | Page 28 | Score: 10.1918
#     • MICROSOFT | Page 28 | Score: 10.5535
#     • MICROSOFT | Page 30 | Score: 11.4201
# ───────────────────────────────────────────────────────
#   Retrieval : 0.6821s
#   Generation: 0.6457s
#   Total     : 1.3278s
# =======================================================
#
#    🎯 Company filter applied: NETFLIX (552/2108 chunks)
#
# =======================================================
#   METHOD  : Vectorless RAG (BM25 keyword search)
# =======================================================
#   QUESTION: How much did Netflix spend on content?
# ───────────────────────────────────────────────────────
#   ANSWER  :
#   For Netflix, the total content spend can be found in the provided context. As of December 31, the total content spend was $16,422,166 (in thousands) for 2025, $15,301,517 (in thousands) for 2024, and $14,197,437 (in thousands) for 2023. This includes both licensed and produced content.
# ───────────────────────────────────────────────────────
#   SOURCES :
#     • NETFLIX | Page 54 | Score: 6.9928
#     • NETFLIX | Page 62 | Score: 9.3922
#     • NETFLIX | Page 4 | Score: 5.0917
#     • NETFLIX | Page 56 | Score: 6.4191
#     • NETFLIX | Page 29 | Score: 6.9873
#     • NETFLIX | Page 47 | Score: 7.4254
#     • NETFLIX | Page 5 | Score: 2.5651
#     • NETFLIX | Page 48 | Score: 8.8946
# ───────────────────────────────────────────────────────
#   Retrieval : 0.5975s
#   Generation: 0.6992s
#   Total     : 1.2967s
# =======================================================
#
#    🎯 Company filter applied: AMAZON (442/2108 chunks)
#
# =======================================================
#   METHOD  : Vectorless RAG (BM25 keyword search)
# =======================================================
#   QUESTION: What is Amazon's cloud revenue?
# ───────────────────────────────────────────────────────
#   ANSWER  :
#   Amazon's cloud revenue, specifically from AWS, is at a $142 billion revenue run rate. This information refers to Amazon.
# ───────────────────────────────────────────────────────
#   SOURCES :
#     • AMAZON | Page 8 | Score: 3.3946
#     • AMAZON | Page 78 | Score: 3.8456
#     • AMAZON | Page 31 | Score: 3.5175
#     • AMAZON | Page 71 | Score: 3.7541
#     • AMAZON | Page 6 | Score: 3.3523
#     • AMAZON | Page 41 | Score: 3.5675
#     • AMAZON | Page 26 | Score: 3.7667
#     • AMAZON | Page 11 | Score: 4.5074
# ───────────────────────────────────────────────────────
#   Retrieval : 0.5794s
#   Generation: 0.4779s
#   Total     : 1.0573s
# =======================================================
